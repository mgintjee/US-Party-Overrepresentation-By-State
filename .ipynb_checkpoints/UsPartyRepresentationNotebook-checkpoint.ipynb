# %%
# Import all of the Utils 
import os
import build_tsv_files
import party_representation_plot_utils
# Out:
# State= Alabama , Total Seats= 7
#
# Seats Remaining= 7
# expected_democratic_seats_float= 2.45
# expected_republican_seats_float= 3.64
# expected_independent_seats_float= 0.91
# expected_democratic_seats_int= 2
# expected_republican_seats_int= 3
# expected_independent_seats_int= 0
# Seats Remaining= 2
# expected_democratic_seats_float= 0.7
# expected_republican_seats_float= 1.04
# expected_independent_seats_float= 0.26
# expected_democratic_seats_int= 0
# expected_republican_seats_int= 1
# expected_independent_seats_int= 0
# Seats Remaining= 1
# expected_democratic_seats_float= 0.35
# expected_republican_seats_float= 0.52
# expected_independent_seats_float= 0.13
# expected_democratic_seats_int= 0
# expected_republican_seats_int= 1
# expected_independent_seats_int= 0
#
# State= Alabama , Seats Remaining= 0
#
#
# State= Alabama , Total Seats= 7
#
# Seats Remaining= 7
# expected_democratic_seats_float= 2.8160919540229883
# expected_republican_seats_float= 4.183908045977011
# ...

# %%
build_tsv_files.print_report_set()
# Out:
# state: New Jersey
# >democratic_seats: 10
# >democratic_support: 38.0
# >republican_seats: 2
# >republican_support: 21.8
# >independent_seats: 0
# >independent_support: 40.2
# Actual Seats        : {'Democratic': 10, 'Republican': 2, 'Independent': 0}
# Expected Seats (W/) : {'Democratic': 5, 'Republican': 2, 'Independent': 5}
# Expected Seats (W/O): {'Democratic': 8, 'Republican': 4, 'Independent': 0}
# state: Vermont
# >democratic_seats: 1
# >democratic_support: 55.0
# >republican_seats: 0
# >republican_support: 30.0
# >independent_seats: 0
# >independent_support: 15.0
# Actual Seats        : {'Democratic': 1, 'Republican': 0, 'Independent': 0}
# Expected Seats (W/) : {'Democratic': 1, 'Republican': 0, 'Independent': 0}
# Expected Seats (W/O): {'Democratic': 1, 'Republican': 0, 'Independent': 0}
# state: Louisiana
# >democratic_seats: 1
# >democratic_support: 42.0
# >republican_seats: 5
# >republican_support: 31.6
# >independent_seats: 0
# >independent_support: 26.4
# ...

# %%
party_representation = build_tsv_files.build_tsv_files()

# %%
party_representation_plot_utils.plot_democratic_representation_without_independents(party_representation)

# %%
party_representation_plot_utils.plot_republican_representation_without_independents(party_representation)

# %%
party_representation_plot_utils.plot_democratic_representation_with_independents(party_representation)

# %%
party_representation_plot_utils.plot_republican_representation_with_independents(party_representation)

# %%
party_representation_plot_utils.plot_independent_representation_with_independents(party_representation)
